# %% [markdown]
# # 3.0_SynAnalyzer_CompileImageMetadata_v2.ipynb
# Created by: JFranco | Created On: 6 AUG 2024 | Last Env: QISHA | Last Run: 26 JAN 2025
#
# This Python notebook is a essentially a utility function for the SynAnalyzer pipeline. It allows the user to generate a metadata spreadsheet for batch analysis given a set of prep IDs. This file will be used in plotting the results from SynAnalyzer.
#
# Version Notes: This version is for when you have access to the prep directories and can just access them rather than having a new folder in the batch folder.

# %%
import pandas as pd
import os
import xlrd
import openpyxl

# %%
#                *** WHAT TO ANALYZE // WHERE TO GET/STORE **
# Batch analysis directory (where the new metadata sheet will be stored)
batchID = 'SynAnalyzer_BclwTGAging'      
# Preps that are included in the analysis
preps = ['WSS_048','WSS_049']
# Metadata fields to grab
mdFields = ['SlideID','ImageName','Turn','RegionID','Freq','NoHCRecon']

# Directories 
#   existing ones 
dirMain = '/Users/joyfranco/Dropbox (Partners HealthCare)/JF_Shared/Data/WSS/'
dirBA = dirMain+'BatchAnalysis/'+batchID+'/'
dirBAMD = dirBA+'Metadata/'

# %%
if not os.path.exists(dirBAMD): os.mkdir(dirBAMD)

# %%
#      *** BEGIN COMPILIATION PROCESS ***
dfMDAll = pd.DataFrame()
# Iterate through the preps and build the new metadata sheet
for prep in preps:
    # Get the metadata sheet
    dirPrep = dirMain+prep+'/'
    dirMD = dirPrep+'Metadata/'
    fnEx = prep+'.Metadata.Imaging.xlsx'
    
    # Load the sheet
    dfEF = pd.read_excel(dirMD+fnEx, sheet_name='63xImages')

    # Add it to the main one
    dfMDAll = pd.concat([dfMDAll, dfEF[mdFields]])

dfMDAll.to_csv(dirBAMD+batchID+'.Metadata.Imaging.csv')

# %%
dfMDAll
# Out:
#        SlideID               ImageName  Turn  RegionID  Freq  NoHCRecon
# 0   WSS_048.01  WSS_048.01.T2.01.Zs.4C     2         1    16        NaN
# 1   WSS_048.01  WSS_048.01.T1.01.Zs.4C     1         1    32       12.0
# 2   WSS_048.01  WSS_048.01.T3.01.Zs.4C     3         1    45       11.0
# 3   WSS_048.02  WSS_048.02.T2.01.Zs.4C     2         1    16        NaN
# 4   WSS_048.02  WSS_048.02.T2.02.Zs.4C     2         2    32       12.0
# 5   WSS_048.02  WSS_048.02.T1.01.Zs.4C     1         1    45       11.0
# 6   WSS_048.03  WSS_048.03.T2.01.Zs.4C     2         1    16        NaN
# 7   WSS_048.03  WSS_048.03.T2.02.Zs.4C     2         2    32       11.0
# 8   WSS_048.03  WSS_048.03.T1.01.Zs.4C     1         1    45       11.0
# 9   WSS_048.04  WSS_048.04.T1.01.Zs.4C     1         1    16        NaN
# 10  WSS_048.04  WSS_048.04.T2.01.Zs.4C     2         1    32       12.0
# 11  WSS_048.04  WSS_048.04.T3.01.Zs.4C     3         1    45       10.0
# 12  WSS_048.05  WSS_048.05.T3.01.Zs.4C     3         1    16        NaN
# 13  WSS_048.05  WSS_048.05.T2.01.Zs.4C     2         1    32       12.0
# 14  WSS_048.05  WSS_048.05.T1.01.Zs.4C     1         1    45       10.0
# 15  WSS_048.06  WSS_048.06.T1.01.Zs.4C     1         1    16        NaN
# 16  WSS_048.06  WSS_048.06.T1.02.Zs.4C     1         2    32       13.0
# 17  WSS_048.06  WSS_048.06.T2.01.Zs.4C     2         1    45        9.0
# 18  WSS_048.07  WSS_048.07.T1.01.Zs.4C     1         1    16        NaN
# 19  WSS_048.07  WSS_048.07.T1.02.Zs.4C     1         2    32        8.0
# 20  WSS_048.07  WSS_048.07.T2.01.Zs.4C     2         1    45        6.0
# 21  WSS_048.08  WSS_048.08.T2.01.Zs.4C     2         1    22        NaN
# 22  WSS_048.08  WSS_048.08.T2.02.Zs.4C     2         2    32        6.0
# 23  WSS_048.08  WSS_048.08.T1.01.Zs.4C     1         1    45       10.0
# 24  WSS_048.09  WSS_048.09.T2.01.Zs.4C     2         1    16        NaN
# 25  WSS_048.09  WSS_048.09.T3.01.Zs.4C     3         1    32        8.0
# 26  WSS_048.09  WSS_048.09.T3.02.Zs.4C     3         2    45        8.0
# 27  WSS_048.10  WSS_048.10.T2.01.Zs.4C     2         1    16        NaN
# 28  WSS_048.10  WSS_048.10.T3.01.Zs.4C     3         1    32        9.0
# 29  WSS_048.10  WSS_048.10.T3.02.Zs.4C     3         2    45        9.0
# 0   WSS_049.01  WSS_049.01.T3.01.Zs.4C     3         1    16        NaN
# 1   WSS_049.01  WSS_049.01.T3.02.Zs.4C     3         2    32       11.0
# 2   WSS_049.01  WSS_049.01.T1.01.Zs.4C     1         1    45       12.0
# 3   WSS_049.03  WSS_049.03.T3.01.Zs.4C     3         1    16        NaN
# 4   WSS_049.03  WSS_049.03.T3.02.Zs.4C     3         2    32       10.0
# 5   WSS_049.03  WSS_049.03.T2.01.Zs.4C     2         1    45        7.0
# 6   WSS_049.04  WSS_049.04.T1.01.Zs.4C     1         1    16        NaN
# 7   WSS_049.04  WSS_049.04.T2.01.Zs.4C     2         1    32       13.0
# 8   WSS_049.04  WSS_049.04.T2.02.Zs.4C     2         1    45        5.0
# 9   WSS_049.05  WSS_049.05.T1.01.Zs.4C     1         1    16        NaN
# 10  WSS_049.05  WSS_049.05.T2.01.Zs.4C     2         1    32       12.0
# 11  WSS_049.05  WSS_049.05.T3.01.Zs.4C     3         1    45       10.0
# 12  WSS_049.06  WSS_049.06.T2.01.Zs.4C     2         1    16        NaN
# 13  WSS_049.06  WSS_049.06.T3.01.Zs.4C     3         1    32       11.0
# 14  WSS_049.06  WSS_049.06.T3.02.Zs.4C     3         2    45        8.0
