# %% [markdown]
# # SynAnalyzer_CompileMetadata.ipynb
# Created by: JFranco | 6 AUG 2024
#
# This Python notebook is a essentially a utility function for the SynAnalyzer pipeline. It allows the user to generate a metadata spreadsheet for batch analysis given a set of prep IDs. This file will be used in plotting the results from SynAnalyzer.

# %%
import pandas as pd
import os
import xlrd
import openpyxl

# %%
#                *** WHAT TO ANALYZE // WHERE TO GET/STORE **
# Batch analysis directory (where the new metadata sheet will be stored)
batchID = 'Ntng1NIHL_2023'     
# Preps that are included in the analysis
preps = ['WSS_022']
# Metadata fields to grab
mdFields = ['SampleID','BlindKey','AnimalID','Sex','DOB','Treatment','NoiseExposed']

# Directories 
#   existing ones 
dirMain = '/Users/joyfranco/Dropbox (Partners HealthCare)/JF_Shared/Data/FromCollaborators/Copeland2024/'
dirPrep = '/Users/joyfranco/Dropbox (Partners HealthCare)/JF_Shared/Data/WSS/'
dirBA = dirMain+batchID+'/'
dirBAMD = dirBA+'Metadata/'

# %%
if not os.path.exists(dirBAMD): os.mkdir(dirBAMD)

# %%
#      *** BEGIN COMPILIATION PROCESS ***
dfMDAll = pd.DataFrame()
# Iterate through the preps and build the new metadata sheet
for prep in preps:
    # Get the metadata sheet
    dirSP = dirPrep+prep+'/'
    dirMD = dirSP+'Metadata/'
    fnEx = prep+'.Metadata.Samples.xlsx'
    
    # Load the sheet
    dfEF = pd.read_excel(dirMD+fnEx)

    # Add it to the main one
    dfMDAll = pd.concat([dfMDAll, dfEF[mdFields]])

dfMDAll.to_csv(dirBAMD+batchID+'.Metadata.Samples.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 11
#       8 fnEx = prep+'.Metadata.Samples.xlsx'
#      10 # Load the sheet
# ---> 11 dfEF = pd.read_excel(dirMD+fnEx)
#      13 # Add it to the main one
#      14 dfMDAll = pd.concat([dfMDAll, dfEF[mdFields]])
#
# File /usr/local/Caskroom/miniconda/base/envs/SynCounting/lib/python3.12/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/Caskroom/miniconda/base/envs/SynCounting/lib/python3.12/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/Caskroom/miniconda/base/envs/SynCounting/lib/python3.12/site-packages/pandas/io/excel/_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File /usr/local/Caskroom/miniconda/base/envs/SynCounting/lib/python3.12/site-packages/pandas/io/excel/_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File /usr/local/Caskroom/miniconda/base/envs/SynCounting/lib/python3.12/site-packages/pandas/io/excel/_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File /usr/local/Caskroom/miniconda/base/envs/SynCounting/lib/python3.12/site-packages/pandas/io/common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/joyfranco/Dropbox (Partners HealthCare)/JF_Shared/Data/WSS/Metadata/WSS_022.Metadata.Samples.xlsx'

# %%
dfMDAll
# Out:
#      SampleID AnimalID  Sex        DOB   Treatment NoiseExposed
# 0  WSS_038.01     I091    F 2024-04-19      HABclw      Exposed
# 1  WSS_038.02     I092    F 2024-04-19     mTagBFP      Exposed
# 2  WSS_038.03     I093    M 2024-04-19  Uninjected         Sham
# 3  WSS_038.04     I094    M 2024-04-19      HABclw         Sham
# 4  WSS_038.05     I095    F 2024-04-19     mTagBFP         Sham
# 5  WSS_038.06     I096    F 2024-04-19  Uninjected      Exposed
# 6  WSS_038.07     I097    F 2024-04-21      HABclw         Sham
# 0  WSS_039.01     I098    M 2024-04-21     mTagBFP      Exposed
# 1  WSS_039.02     I099    F 2024-04-21  Uninjected      Exposed
# 2  WSS_039.03     I100    F 2024-04-21      HABclw      Exposed
# 3  WSS_039.04     I101    M 2024-04-21     mTagBFP         Sham
# 4  WSS_039.05     I102    M 2024-04-21  Uninjected         Sham
# 5  WSS_039.06     I103    F 2024-04-21      HABclw      Exposed
# 6  WSS_039.07     I104    F 2024-04-21     mTagBFP      Exposed
# 7  WSS_039.08     I105    F 2024-04-21  Uninjected      Exposed
# 0  WSS_040.01     I106    M 2024-05-08      HABclw         Sham
# 1  WSS_040.02     I107    M 2024-05-08      HABclw      Exposed
# 2  WSS_040.03     I108    F 2024-05-08     mTagBFP      Exposed
# 3  WSS_040.04     I109    M 2024-05-08  Uninjected      Exposed
# 4  WSS_040.05     I110    M 2024-05-08     mTagBFP         Sham
# 0  WSS_041.01     I111    M 2024-05-08     mTagBFP         Sham
# 1  WSS_041.02     I112    M 2024-05-08  Uninjected         Sham
# 2  WSS_041.03     I113    F 2024-05-08      HABclw         Sham
# 3  WSS_041.04     I115    F 2024-05-16  Uninjected         Sham
# 4  WSS_041.05     I116  NaN 2024-05-16      HABclw         Sham
# 5  WSS_041.06     I117    F 2024-05-16      HABclw      Exposed
